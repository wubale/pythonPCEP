# %% [markdown]
# ## Exercises
# ### Write the pseudocode for these problems.
#
# #### Define the problem by constructing an IPO diagram showing input, output, and processing steps
# Ask yourself
# - What control structures (sequence, selection and repetition) are required?
# - What variables are required?
#
# Show a check of your solution with **test data** for at least **two valid test cases**
# If you use the numbers provided in the example then the correct pseudocode will calculate the same result.

# %% [markdown]
# #### 1. Find the average score
# A program is needed to prompt the user operator for exam scores, calculate the average score and display the result to the screen. The average score is calculated as the sum of the scores divided by the number of scores.
#
# Inputs: exam scores
# Output: Average
# Process: using addition and division operator. First, Sum of the given exam scores ,and secondly, divide the sum to the counts of exam scores to get the Average score.
#
# The Formula(Algorithm): (x1+x2+x3+x4+x5)/5
#
#
# Starts
#     Request the user to enter x1
#     Get x1
#     Request the user to enter x2
#     Get x2
#     Request the user to enter x3
#     Get x3
#     Request the user to enter x4
#     Get x4
#     Request the user to enter x5
#     Get x5
#
#     Average=(x1+x2+x3+x4+x5)/5
#
# Ends
#
# #Example:
#
# User enters 2;
# User enters 3;
# User enters 4;
# User enters 5;
# User enters 6;
#
# Average=(2+3+4+5+6)/5
#
# Average=4

# %% [markdown]
# #### 2. How much water runs off a roof in a rain storm?
# To calculate the runoff from any given rainfall: Take the dimensions of the footprint of the roof and convert them to inches. (So, a 50' x 20' roof is 600" x 240"). Multiply the roof dimensions by the number of inches of rainfall. As an example, 600" x 240" x 1" = 144,000 cubic inches of water for an inch of rainfall. Divide that result by 231 to get the number of gallons (because 1 gallon = 231 cubic inches). (144,000/231 = 623.38).
#
# Input: width of the roof in a feet, length of the roof in a feet, rainfall in inches
# Output: amount of runoff rain in gallon
# Process:
#
# Formula= (((width*length)*5)*Rain)/231
#
# Starts
#     Request the user to enter roof's width in feet
#     Get width
#     Request the user to enter roof's length in feet
#     Get lengt
#     Request the user to enter rainfall amount in inch
#     Get rainfall in inch
#
#
#     width_inch=width*12
#     length_inch=length*12
#
#     total= width_inch*lengt_inch*5
#     gallon= total/231
#
#
#
#     #Example
#
#     Enter roof's width in feet=10
#     Enter roof's length in feet=20
#     Enter rainfall amount in inches=2.4
#
#     width_inch= 120
#     length_inch= 240
#     total=144000
#     gallon=623.38
#
# End

# %% [markdown]
# Type Markdown and LaTeX:  𝛼2

# %% [markdown]
# #### 3. Process customer record
# A program is required to read a customer’s name, a purchase amount and a tax code. The tax code has been validated and will be one of the following: 0 tax exempt (0%) 1 state sales tax only (3%) 2 federal and state sales tax (5%) 3 special sales tax (7%) The program must then compute the sales tax and the total amount due,and print the customer’s name, purchase amount, sales tax and total amount due.
#
# Input: Customer's name, purchase amount, a tax code
# Output: Total amount due, and print the customer’s name, purchase amount, sales tax and total amount due.
# Process:
# Start
#     Request the customer's name
#     Get name
#     Request the user's purchase amount
#     Get purchase amount
#     Request the user tax code
#     Get tax code
#         If tax code is 0
#             Set tax_percentage=0%
#         If tax code is 1
#             Set tax_percentage=3%
#         If tax code is 2
#             Set tax_percentage=5%
#         If tax code is 3
#             Set tax_percentage=7%
#         Else
#             Show error message
#
#
#      sales_tax= purchase amount *tax code
#      total_amount= purchase amount+sales_tax
#      print Customer's name, purchase amount, sales_tax, and total_amount
# End
#
# #Example
# Enter customer's name: Belay
# Enter purchase amount: 500.00
# Enter tax code:0
# sales_tax:0
# total_amount:500.00
#
#
# #Belay:
# #purchase amount: 500.00
# #sales_tax:0
# #total_amount:500.00

# %% [markdown]
# Type Markdown and LaTeX:  𝛼2

# %% [markdown]
# #### 4. Calculate employee's pay
# A program is required by a company to read an employee’s number, pay rate and the number of hours worked in a week. The program is then to validate the pay rate field and the hours worked field and, if valid, compute the employee’s weekly pay and then print it and the input data.
#
# Validation: According to the company’s rules, the maximum hours an employee can work per week is 60 hours, and the maximum hourly rate is $25.00 per hour. If the hours worked field or the hourly rate field is out of range, the input data and an appropriate message are to be printed and the employee’s weekly pay is not to be calculated.
#
# Weekly pay calculation: Weekly pay is calculated as hours worked times pay rate. If more than 35 hours are worked, payment for the overtime hours worked is calculated at time-and-a-half.
#
#
# Input: Employee's number, pay rate, and number of hours worked in a week
# Output: Employee's weekly pay, employee's number, pay rate, and hours worked in a week
# Process
# Algorithm
# Rule: hoursWorked is <= 60 hours and
#       hourlyRate is <= $25.00
#       overtimeHours = hoursWorked-35
#       overtimePay= overtimeHours*1.5*payRate
#       normalHours= hoursWorked(<=35 hours)
#       weeklyPay= (normalHours*payRate)+ overtimePay
#
#
# Pseudocode:
# Start
#     Request the user for Employee number
#         Get Employee number
#     Request employee's payRate
#         Get PayRate
#     Request the eployee hoursWorked
#         Get hoursWorked
#       If hoursWorked>=60
#           Request the user to enter hoursWorked
#             Get hoursWorked
#             .
#             .

# %% [markdown]
# Type Markdown and LaTeX:  𝛼2
